# %% [markdown]
# # Aludecor Sales Analysis
#
# import pandas as pd
# import matplotlib.pyplot as plt
# import seaborn as sns

# %%
pip install fpdf
# Out:
# Requirement already satisfied: fpdf in c:\users\anjali\anaconda3\lib\site-packages (1.7.2)
# Note: you may need to restart the kernel to use updated packages.

# %% [raw]
# pip install Pyppeteer

# %%
pip install nbconvert
# Out:
# Requirement already satisfied: nbconvert in c:\users\anjali\anaconda3\lib\site-packages (6.4.4)
# Requirement already satisfied: beautifulsoup4 in c:\users\anjali\anaconda3\lib\site-packages (from nbconvert) (4.11.1)
# Requirement already satisfied: mistune<2,>=0.8.1 in c:\users\anjali\anaconda3\lib\site-packages (from nbconvert) (0.8.4)
# Requirement already satisfied: traitlets>=5.0 in c:\users\anjali\anaconda3\lib\site-packages (from nbconvert) (5.1.1)
# Requirement already satisfied: jupyterlab-pygments in c:\users\anjali\anaconda3\lib\site-packages (from nbconvert) (0.1.2)
# Requirement already satisfied: pandocfilters>=1.4.1 in c:\users\anjali\anaconda3\lib\site-packages (from nbconvert) (1.5.0)
# Requirement already satisfied: nbclient<0.6.0,>=0.5.0 in c:\users\anjali\anaconda3\lib\site-packages (from nbconvert) (0.5.13)
# Requirement already satisfied: nbformat>=4.4 in c:\users\anjali\anaconda3\lib\site-packages (from nbconvert) (5.3.0)
# Requirement already satisfied: pygments>=2.4.1 in c:\users\anjali\anaconda3\lib\site-packages (from nbconvert) (2.11.2)
# Requirement already satisfied: bleach in c:\users\anjali\anaconda3\lib\site-packages (from nbconvert) (4.1.0)
# Requirement already satisfied: jinja2>=2.4 in c:\users\anjali\anaconda3\lib\site-packages (from nbconvert) (2.11.3)
# Requirement already satisfied: testpath in c:\users\anjali\anaconda3\lib\site-packages (from nbconvert) (0.5.0)
# Requirement already satisfied: entrypoints>=0.2.2 in c:\users\anjali\anaconda3\lib\site-packages (from nbconvert) (0.4)
# Requirement already satisfied: defusedxml in c:\users\anjali\anaconda3\lib\site-packages (from nbconvert) (0.7.1)
# Requirement already satisfied: jupyter-core in c:\users\anjali\anaconda3\lib\site-packages (from nbconvert) (4.9.2)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\users\anjali\anaconda3\lib\site-packages (from jinja2>=2.4->nbconvert) (2.0.1)
# Requirement already satisfied: jupyter-client>=6.1.5 in c:\users\anjali\anaconda3\lib\site-packages (from nbclient<0.6.0,>=0.5.0->nbconvert) (6.1.12)
# Requirement already satisfied: nest-asyncio in c:\users\anjali\anaconda3\lib\site-packages (from nbclient<0.6.0,>=0.5.0->nbconvert) (1.5.5)
# Requirement already satisfied: tornado>=4.1 in c:\users\anjali\anaconda3\lib\site-packages (from jupyter-client>=6.1.5->nbclient<0.6.0,>=0.5.0->nbconvert) (6.1)
# Requirement already satisfied: python-dateutil>=2.1 in c:\users\anjali\anaconda3\lib\site-packages (from jupyter-client>=6.1.5->nbclient<0.6.0,>=0.5.0->nbconvert) (2.8.2)
# Requirement already satisfied: pyzmq>=13 in c:\users\anjali\anaconda3\lib\site-packages (from jupyter-client>=6.1.5->nbclient<0.6.0,>=0.5.0->nbconvert) (22.3.0)
# Requirement already satisfied: pywin32>=1.0 in c:\users\anjali\anaconda3\lib\site-packages (from jupyter-core->nbconvert) (302)
# Requirement already satisfied: jsonschema>=2.6 in c:\users\anjali\anaconda3\lib\site-packages (from nbformat>=4.4->nbconvert) (4.4.0)
# Requirement already satisfied: fastjsonschema in c:\users\anjali\anaconda3\lib\site-packages (from nbformat>=4.4->nbconvert) (2.15.1)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in c:\users\anjali\anaconda3\lib\site-packages (from jsonschema>=2.6->nbformat>=4.4->nbconvert) (0.18.0)
# Requirement already satisfied: attrs>=17.4.0 in c:\users\anjali\anaconda3\lib\site-packages (from jsonschema>=2.6->nbformat>=4.4->nbconvert) (21.4.0)
# Requirement already satisfied: six>=1.5 in c:\users\anjali\anaconda3\lib\site-packages (from python-dateutil>=2.1->jupyter-client>=6.1.5->nbclient<0.6.0,>=0.5.0->nbconvert) (1.16.0)
# Requirement already satisfied: soupsieve>1.2 in c:\users\anjali\anaconda3\lib\site-packages (from beautifulsoup4->nbconvert) (2.3.1)
# Requirement already satisfied: webencodings in c:\users\anjali\anaconda3\lib\site-packages (from bleach->nbconvert) (0.5.1)
# Requirement already satisfied: packaging in c:\users\anjali\anaconda3\lib\site-packages (from bleach->nbconvert) (21.3)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\users\anjali\anaconda3\lib\site-packages (from packaging->bleach->nbconvert) (3.0.4)
# Note: you may need to restart the kernel to use updated packages.

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
from fpdf import FPDF

# %%
df=pd.read_csv("Important sheets - Customer_Masters.csv")
df2=pd.read_csv("Important sheets - InvoiceRegister.csv")
df3=pd.read_csv("Important sheets - SalesActiveEmpList.csv")

# %%
df2.head()
# Out:
#    INV CREATION DT  SALES ORDER  BILL TO CODE  Ship To Code  Invoice Number  \
# 0       01-04-2022   3100077188     100001859     100001859        90000546
# 1       01-04-2022   3100077188     100001859     100001859        90000546
# 2       01-04-2022   3100079271     100001257     100001257      1804012199
# 3       01-04-2022   3100079271     100001257     100001257      1804012199
# 4       01-04-2022   3100079271     100001257     100001257      1804012199
#
#    PLANT    BILL TO GSTIN SALES GROUP DESCRIPTION NEW  \
# 0   3400  29ABIFM0400F1ZO              Karnataka Team
# 1   3400  29ABIFM0400F1ZO              Karnataka Team
# 2   3100  33AANCS1511L1ZD             Tamil_Nadu Team
# 3   3100  33AANCS1511L1ZD             Tamil_Nadu Team
# 4   3100  33AANCS1511L1ZD             Tamil_Nadu Team
#
#        MATERIAL DESCRIPTION MATERIAL TYPE  ...  TOT INV VAL(LC)  UGST VALUE  \
# 0  AL312-AD94-3050mmx1220mm          ZFRT  ...          7592.91           0
# 1  AL312-AD94-3660mmx1220mm          ZFRT  ...          6074.09           0
# 2  AL332-AD73-3050mmx1220mm          ZFRT  ...         13475.35           0
# 3  AL332-AD73-2440mmx1220mm          ZFRT  ...         10780.98           0
# 4  AL332-AD73-3660mmx1220mm          ZFRT  ...         16169.67           0
#
#    BASIC RATE  Inv Qty  Qty in SQM                  Material No  \
# 0      698.74        3      11.163  AA0312-01-000AD94-3050X1220
# 1      698.74        2       8.930  AA0312-01-000AD94-3660X1220
# 2      870.73        4      14.884  AA0332-01-000AD73-3050X1220
# 3      870.73        4      11.908  AA0332-01-000AD73-2440X1220
# 4      870.73        4      17.860  AA0332-01-000AD73-3660X1220
#
#    Sales Person Code  Aludecorian Name                Team_Name  \
# 0             T29016      Dayanand_D_S         Karnataka/Kerala
# 1             T29016      Dayanand_D_S         Karnataka/Kerala
# 2             T28017   Nisanth_Natesan  AP/Telangana/Tamil_Nadu
# 3             T28017   Nisanth_Natesan  AP/Telangana/Tamil_Nadu
# 4             T28017   Nisanth_Natesan  AP/Telangana/Tamil_Nadu
#
#                         Customer Name
# 0                     Mono Sign Store
# 1                     Mono Sign Store
# 2  Sri Vijaya Plywood Private Limited
# 3  Sri Vijaya Plywood Private Limited
# 4  Sri Vijaya Plywood Private Limited
#
# [5 rows x 28 columns]

# %%
df2.tail()
# Out:
#        INV CREATION DT  SALES ORDER  BILL TO CODE  Ship To Code  \
# 14450       18-05-2022   3100082800     100002028     100002028
# 14451       18-05-2022   3100082800     100002028     100002028
# 14452       18-05-2022   3100082800     100002028     100002028
# 14453       18-05-2022   3100082800     100002028     100002028
# 14454       18-05-2022   3100082800     100002028     100002028
#
#        Invoice Number  PLANT    BILL TO GSTIN SALES GROUP DESCRIPTION NEW  \
# 14450      1204004214   2300  33AABCS4855P1ZW              Corporate Team
# 14451      1204004214   2300  33AABCS4855P1ZW              Corporate Team
# 14452      1204004214   2300  33AABCS4855P1ZW              Corporate Team
# 14453      1204004214   2300  33AABCS4855P1ZW              Corporate Team
# 14454      1204004214   2300  33AABCS4855P1ZW              Corporate Team
#
#              MATERIAL DESCRIPTION MATERIAL TYPE  ...  TOT INV VAL(LC)  \
# 14450  AL33D-PP1006-4000mmx1250mm          ZFRT  ...        343725.41
# 14451  AL33D-PP1006-3000mmx1250mm          ZFRT  ...        324820.51
# 14452  AL33D-PP1005-4000mmx1250mm          ZFRT  ...        260656.87
# 14453  AL33D-PP1007-2800mmx1250mm          ZFRT  ...          9624.31
# 14454  AL33D-PP1007-2500mmx1250mm          ZFRT  ...        356597.60
#
#        UGST VALUE  BASIC RATE  Inv Qty  Qty in SQM  \
# 14450           0      1300.0       50     250.000
# 14451           0      1300.0       63     236.250
# 14452           0      1300.0       35     175.000
# 14453           0      1300.0        2       7.000
# 14454           0      1300.0       83     259.375
#
#                        Material No  Sales Person Code  Aludecorian Name  \
# 14450  AA033D-01-0PP1006-4000X1250             T29017        Pranav_P_S
# 14451  AA033D-01-0PP1006-3000X1250             T29017        Pranav_P_S
# 14452  AA033D-01-0PP1005-4000X1250             T29017        Pranav_P_S
# 14453  AA033D-01-0PP1007-2800X1250             T29017        Pranav_P_S
# 14454  AA033D-01-0PP1007-2500X1250             T29017        Pranav_P_S
#
#                    Team_Name                  Customer Name
# 14450  Corporate_Sales-South  Sinex Systems Private Limited
# 14451  Corporate_Sales-South  Sinex Systems Private Limited
# 14452  Corporate_Sales-South  Sinex Systems Private Limited
# 14453  Corporate_Sales-South  Sinex Systems Private Limited
# 14454  Corporate_Sales-South  Sinex Systems Private Limited
#
# [5 rows x 28 columns]

# %%
df2.shape
# Out:
# (14455, 28)

# %%
df2.columns
# Out:
# Index([' INV CREATION DT', 'SALES ORDER', 'BILL TO CODE', 'Ship To Code',
#        'Invoice Number', 'PLANT', 'BILL TO GSTIN',
#        'SALES GROUP DESCRIPTION NEW', 'MATERIAL DESCRIPTION', 'MATERIAL TYPE',
#        'OTHER CHARGES', 'PACKING CHARGES', 'DELIVERY CHARGES', 'NET VAL (LC)',
#        'CGST VALUE', 'SGST VALUE', 'IGST VALUE', 'TCS VALUE',
#        'TOT INV VAL(LC)', 'UGST VALUE', 'BASIC RATE', 'Inv Qty', 'Qty in SQM',
#        'Material No', 'Sales Person Code', 'Aludecorian Name', 'Team_Name',
#        'Customer Name'],
#       dtype='object')

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14455 entries, 0 to 14454
# Data columns (total 28 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0    INV CREATION DT             14455 non-null  object
#  1   SALES ORDER                  14455 non-null  int64
#  2   BILL TO CODE                 14455 non-null  int64
#  3   Ship To Code                 14455 non-null  int64
#  4   Invoice Number               14455 non-null  int64
#  5   PLANT                        14455 non-null  int64
#  6   BILL TO GSTIN                14413 non-null  object
#  7   SALES GROUP DESCRIPTION NEW  14455 non-null  object
#  8   MATERIAL DESCRIPTION         14455 non-null  object
#  9   MATERIAL TYPE                14455 non-null  object
#  10  OTHER CHARGES                14455 non-null  float64
#  11  PACKING CHARGES              14455 non-null  float64
#  12  DELIVERY CHARGES             14455 non-null  float64
#  13  NET VAL (LC)                 14455 non-null  float64
#  14  CGST VALUE                   14455 non-null  float64
#  15  SGST VALUE                   14455 non-null  float64
#  16  IGST VALUE                   14455 non-null  float64
#  17  TCS VALUE                    14455 non-null  int64
#  18  TOT INV VAL(LC)              14455 non-null  float64
#  19  UGST VALUE                   14455 non-null  int64
#  20  BASIC RATE                   14455 non-null  float64
#  21  Inv Qty                      14455 non-null  int64
#  22  Qty in SQM                   14455 non-null  float64
#  23  Material No                  14455 non-null  object
#  24  Sales Person Code            14455 non-null  object
#  25  Aludecorian Name             14453 non-null  object
#  26  Team_Name                    14453 non-null  object
#  27  Customer Name                14446 non-null  object
# dtypes: float64(10), int64(8), object(10)
# memory usage: 3.1+ MB

# %%
df2.isnull().sum()
# Out:
#  INV CREATION DT                0
# SALES ORDER                     0
# BILL TO CODE                    0
# Ship To Code                    0
# Invoice Number                  0
# PLANT                           0
# BILL TO GSTIN                  42
# SALES GROUP DESCRIPTION NEW     0
# MATERIAL DESCRIPTION            0
# MATERIAL TYPE                   0
# OTHER CHARGES                   0
# PACKING CHARGES                 0
# DELIVERY CHARGES                0
# NET VAL (LC)                    0
# CGST VALUE                      0
# SGST VALUE                      0
# IGST VALUE                      0
# TCS VALUE                       0
# TOT INV VAL(LC)                 0
# UGST VALUE                      0
# BASIC RATE                      0
# Inv Qty                         0
# Qty in SQM                      0
# Material No                     0
# Sales Person Code               0
# Aludecorian Name                2
# Team_Name                       2
# Customer Name                   9
# dtype: int64

# %%
df2=df2.dropna()
df2.isnull().sum()
# Out:
#  INV CREATION DT               0
# SALES ORDER                    0
# BILL TO CODE                   0
# Ship To Code                   0
# Invoice Number                 0
# PLANT                          0
# BILL TO GSTIN                  0
# SALES GROUP DESCRIPTION NEW    0
# MATERIAL DESCRIPTION           0
# MATERIAL TYPE                  0
# OTHER CHARGES                  0
# PACKING CHARGES                0
# DELIVERY CHARGES               0
# NET VAL (LC)                   0
# CGST VALUE                     0
# SGST VALUE                     0
# IGST VALUE                     0
# TCS VALUE                      0
# TOT INV VAL(LC)                0
# UGST VALUE                     0
# BASIC RATE                     0
# Inv Qty                        0
# Qty in SQM                     0
# Material No                    0
# Sales Person Code              0
# Aludecorian Name               0
# Team_Name                      0
# Customer Name                  0
# dtype: int64

# %%
df2.describe()
# Out:
#         SALES ORDER  BILL TO CODE  Ship To Code  Invoice Number         PLANT  \
# count  1.441100e+04  1.441100e+04  1.441100e+04    1.441100e+04  14411.000000
# mean   3.105439e+09  1.022001e+08  1.000022e+08    1.684903e+09   2914.072583
# std    6.020545e+07  4.392967e+07  2.013273e+03    1.124457e+09    504.928251
# min    3.100068e+09  1.000000e+08  1.000000e+08    9.000055e+07   2200.000000
# 25%    3.100080e+09  1.000007e+08  1.000007e+08    1.304011e+09   2400.000000
# 50%    3.100081e+09  1.000012e+08  1.000013e+08    1.404014e+09   3000.000000
# 75%    3.100083e+09  1.000022e+08  1.000032e+08    1.804013e+09   3200.000000
# max    3.830001e+09  9.800000e+08  1.000065e+08    9.451000e+09   6100.000000
#
#        OTHER CHARGES  PACKING CHARGES  DELIVERY CHARGES  NET VAL (LC)  \
# count   14411.000000     14411.000000      14411.000000  1.441100e+04
# mean        0.125618         4.623811        149.689464  3.404852e+04
# std         5.515975        63.756877        965.922244  1.040885e+05
# min        -1.170000         0.000000      -6407.830000 -1.243699e+06
# 25%         0.000000         0.000000          0.000000  5.559660e+03
# 50%         0.000000         0.000000          0.000000  1.243150e+04
# 75%         0.000000         0.000000          0.000000  2.651842e+04
# max       480.000000      3311.930000      35000.000000  3.849697e+06
#
#           CGST VALUE     SGST VALUE     IGST VALUE  TCS VALUE  \
# count   14411.000000   14411.000000   14411.000000    14411.0
# mean     1293.189895    1293.189895    3542.353711        0.0
# std      4091.492470    4091.492470   17389.609399        0.0
# min    -18917.340000  -18917.340000 -223865.800000        0.0
# 25%         0.000000       0.000000       0.000000        0.0
# 50%       457.290000     457.290000       0.000000        0.0
# 75%      1317.590000    1317.590000    1308.740000        0.0
# max    190080.070000  190080.070000  692945.540000        0.0
#
#        TOT INV VAL(LC)  UGST VALUE    BASIC RATE       Inv Qty    Qty in SQM
# count     1.441100e+04     14411.0  14411.000000  14411.000000  14411.000000
# mean      4.018273e+04         0.0   1038.484955      8.562071     32.091996
# std       1.228649e+05         0.0    447.603764     18.881925     70.192801
# min      -1.467565e+06         0.0    429.990000    -88.000000   -278.784000
# 25%       6.560400e+03         0.0    773.990000      2.000000      5.954000
# 50%       1.466920e+04         0.0    945.980000      4.000000     14.885000
# 75%       3.129175e+04         0.0   1214.730000      9.000000     29.770000
# max       4.542643e+06         0.0   7524.860000    550.000000   1786.000000

# %%
df2['Month']=df2[" INV CREATION DT"].str[3:5]
df2['Month']=df2['Month'].astype('int32')
df2.head()
# Out:
#    INV CREATION DT  SALES ORDER  BILL TO CODE  Ship To Code  Invoice Number  \
# 0       01-04-2022   3100077188     100001859     100001859        90000546
# 1       01-04-2022   3100077188     100001859     100001859        90000546
# 2       01-04-2022   3100079271     100001257     100001257      1804012199
# 3       01-04-2022   3100079271     100001257     100001257      1804012199
# 4       01-04-2022   3100079271     100001257     100001257      1804012199
#
#    PLANT    BILL TO GSTIN SALES GROUP DESCRIPTION NEW  \
# 0   3400  29ABIFM0400F1ZO              Karnataka Team
# 1   3400  29ABIFM0400F1ZO              Karnataka Team
# 2   3100  33AANCS1511L1ZD             Tamil_Nadu Team
# 3   3100  33AANCS1511L1ZD             Tamil_Nadu Team
# 4   3100  33AANCS1511L1ZD             Tamil_Nadu Team
#
#        MATERIAL DESCRIPTION MATERIAL TYPE  ...  UGST VALUE  BASIC RATE  \
# 0  AL312-AD94-3050mmx1220mm          ZFRT  ...           0      698.74
# 1  AL312-AD94-3660mmx1220mm          ZFRT  ...           0      698.74
# 2  AL332-AD73-3050mmx1220mm          ZFRT  ...           0      870.73
# 3  AL332-AD73-2440mmx1220mm          ZFRT  ...           0      870.73
# 4  AL332-AD73-3660mmx1220mm          ZFRT  ...           0      870.73
#
#    Inv Qty  Qty in SQM                  Material No  Sales Person Code  \
# 0        3      11.163  AA0312-01-000AD94-3050X1220             T29016
# 1        2       8.930  AA0312-01-000AD94-3660X1220             T29016
# 2        4      14.884  AA0332-01-000AD73-3050X1220             T28017
# 3        4      11.908  AA0332-01-000AD73-2440X1220             T28017
# 4        4      17.860  AA0332-01-000AD73-3660X1220             T28017
#
#    Aludecorian Name                Team_Name  \
# 0      Dayanand_D_S         Karnataka/Kerala
# 1      Dayanand_D_S         Karnataka/Kerala
# 2   Nisanth_Natesan  AP/Telangana/Tamil_Nadu
# 3   Nisanth_Natesan  AP/Telangana/Tamil_Nadu
# 4   Nisanth_Natesan  AP/Telangana/Tamil_Nadu
#
#                         Customer Name  Month
# 0                     Mono Sign Store      4
# 1                     Mono Sign Store      4
# 2  Sri Vijaya Plywood Private Limited      4
# 3  Sri Vijaya Plywood Private Limited      4
# 4  Sri Vijaya Plywood Private Limited      4
#
# [5 rows x 29 columns]

# %%
#Which was the best month for sales? 


df2["Qty"]=df2["Qty in SQM"].astype("int32")
df2["Sales"]=df2["NET VAL (LC)"].astype("int32")

# %%
results=df2.groupby('Month').sum()

# %%
df2.groupby('Month').sum()['Sales']
# Out:
# Month
# 4    300846759
# 5    189819497
# Name: Sales, dtype: int32

# %%
#which Team has the highest number of sales?


results=df2.groupby('Team_Name').sum()
results
# Out:
#                                SALES ORDER  BILL TO CODE  Ship To Code  \
# Team_Name
# AP/Telangana/Tamil_Nadu      8859671899870  285603936599  285604184507
# Bihar                         269707051349    8700123005    8700123005
# Central_UP/UK                1111288846529   35800653772   35800736180
# Commercial                    139503685126    4500100732    4500110101
# Corporate_Sales-East         1065517579217   34300436083   34300554966
# Corporate_Sales-North        2689049683631   86601619751   86603026346
# Corporate_Sales-South        2207626976442   71001370119   71001659651
# Corporate_Sales-West         1613502043222   52001499130   52001975999
# Delhi_NCR/Western_UP         3248885299701  104802094314  104802588985
# Gujarat                      3012188461841   97001890848   97002014720
# Jharkhand/Odisha             1209220465728   38701001957   38701003253
# Karnataka/Kerala             5243697545946  169103125736  169103220972
# Madhya_Pradesh/Chhattisgarh  1890688909196   60801240671   60801699524
# Maharashtra                  4075154457033  131102143463  131102991655
# Project_Sales-East             43401120423    1400052827    1400051907
# Project_Sales-North           344108639353   11100312606   11100466028
# Project_Sales-South           372009720917   12000344594   12000443429
# Project_Sales-West            405019906305   12900441111   12900496462
# Punjab/Haryana               1222161916291   39400993080   39401304122
# Rajasthan                     799820950264   25800591044   25800740634
# WB/North_East                4930255546351  190182330820  158502402964
#
#                              Invoice Number    PLANT  OTHER CHARGES  \
# Team_Name
# AP/Telangana/Tamil_Nadu       5081739770024  8909500           0.00
# Bihar                          113648925363   225800           0.00
# Central_UP/UK                  497290660614   861000          31.00
# Commercial                      79701463292   127000           6.98
# Corporate_Sales-East           442211134544   870400           0.00
# Corporate_Sales-North         1166149391703  2072200        1517.78
# Corporate_Sales-South          909737541660  2190800           0.00
# Corporate_Sales-West           883055797739  1397200           8.09
# Delhi_NCR/Western_UP          1470206197664  2514600          31.52
# Gujarat                       2123508650010  2881800           0.00
# Jharkhand/Odisha               552106555245  1018000           0.00
# Karnataka/Kerala              2100548469619  5662400           0.00
# Madhya_Pradesh/Chhattisgarh    434378997938  2078300           0.00
# Maharashtra                   3005088334963  4096700           0.00
# Project_Sales-East              18256148740    36400           0.00
# Project_Sales-North            142044855511   259500         203.91
# Project_Sales-South            187580761432   346300           0.00
# Project_Sales-West             217884728070   337900           0.00
# Punjab/Haryana                 553193334949   945600           8.00
# Rajasthan                      371835447413   626400           3.00
# WB/North_East                 3930965011356  4536900           0.00
#
#                              PACKING CHARGES  DELIVERY CHARGES  NET VAL (LC)  \
# Team_Name
# AP/Telangana/Tamil_Nadu             12400.01           1200.00   53900401.29
# Bihar                                   0.00            800.00    2177617.71
# Central_UP/UK                           0.00          -7500.00    9418520.52
# Commercial                              0.00          37500.00    4098104.25
# Corporate_Sales-East                    0.00         246501.90   14075824.17
# Corporate_Sales-North               40730.00         763811.91   62132190.15
# Corporate_Sales-South                7136.73         286565.52   42692456.94
# Corporate_Sales-West                 4767.00         585203.10   36909059.44
# Delhi_NCR/Western_UP                  750.00          31101.00   23428876.76
# Gujarat                                 0.00          35800.02   24235508.70
# Jharkhand/Odisha                        0.00           8600.04    6503902.33
# Karnataka/Kerala                        0.00           4000.00   25166589.96
# Madhya_Pradesh/Chhattisgarh             0.00          14900.00   15288379.79
# Maharashtra                             0.00          47600.00   31182552.52
# Project_Sales-East                      0.00              0.00    2358015.24
# Project_Sales-North                     0.00          36051.00   24772210.78
# Project_Sales-South                   700.00          21800.00   31848274.29
# Project_Sales-West                      0.00           8636.36   38745732.02
# Punjab/Haryana                        150.00              0.00    9045813.60
# Rajasthan                               0.00              0.00    5211438.43
# WB/North_East                           0.00          34604.01   27481785.33
#
#                              CGST VALUE  ...  IGST VALUE  TCS VALUE  \
# Team_Name                                ...
# AP/Telangana/Tamil_Nadu      3911596.76  ...  1878876.22          0
# Bihar                              0.00  ...   391971.29          0
# Central_UP/UK                  85373.59  ...  1524586.25          0
# Commercial                    221368.99  ...   294920.77          0
# Corporate_Sales-East          457200.07  ...  1619247.69          0
# Corporate_Sales-North         611961.64  ...  9959871.09          0
# Corporate_Sales-South        1154460.66  ...  5375721.09          0
# Corporate_Sales-West          668202.92  ...  5307225.12          0
# Delhi_NCR/Western_UP          890192.41  ...  2436811.42          0
# Gujarat                      1907533.24  ...   547324.27          0
# Jharkhand/Odisha              264620.22  ...   641462.23          0
# Karnataka/Kerala             2188893.66  ...   152198.35          0
# Madhya_Pradesh/Chhattisgarh   504543.67  ...  1742821.89          0
# Maharashtra                  1611149.66  ...  2390556.73          0
# Project_Sales-East            146084.58  ...   132273.60          0
# Project_Sales-North           168339.63  ...  4122318.88          0
# Project_Sales-South           261950.46  ...  5208788.35          0
# Project_Sales-West           1130380.30  ...  4713471.14          0
# Punjab/Haryana                     0.00  ...  1628246.35          0
# Rajasthan                          0.00  ...   938058.57          0
# WB/North_East                2452307.12  ...    42108.03          0
#
#                              TOT INV VAL(LC)  UGST VALUE  BASIC RATE  Inv Qty  \
# Team_Name
# AP/Telangana/Tamil_Nadu          63603050.84           0  2922337.26    16290
# Bihar                             2569589.00           0    76537.17      801
# Central_UP/UK                    11113955.00           0   381132.77     2432
# Commercial                        4835763.00           0    35399.14     2157
# Corporate_Sales-East             16609472.00           0   343746.98     3687
# Corporate_Sales-North            73316826.27           0   947039.24    15625
# Corporate_Sales-South            50381888.00           0   749596.21     9845
# Corporate_Sales-West             43552823.00           0   597198.52     8865
# Delhi_NCR/Western_UP             27646073.00           0  1082326.66     7106
# Gujarat                          28598152.00           0   939146.69     7239
# Jharkhand/Odisha                  7674605.00           0   329277.68     2302
# Karnataka/Kerala                 29696714.00           0  1513381.52     8532
# Madhya_Pradesh/Chhattisgarh      18043335.00           0   575996.65     4889
# Maharashtra                      36807019.00           0  1342145.83     9710
# Project_Sales-East                2782458.00           0    30884.22      337
# Project_Sales-North              29233417.00           0   321903.03     2981
# Project_Sales-South              37616902.65           0   301005.55     3255
# Project_Sales-West               45738750.18           0   416200.15     3999
# Punjab/Haryana                   10674200.00           0   411492.11     2413
# Rajasthan                         6149497.00           0   251653.08     1573
# WB/North_East                    32428786.32           0  1397206.23     9350
#
#                              Qty in SQM  Month    Qty     Sales
# Team_Name
# AP/Telangana/Tamil_Nadu       60577.824  12427  58634  53899001
# Bihar                          2802.705    369   2749   2177570
# Central_UP/UK                 10128.338   1497   9912   9418336
# Commercial                     8262.045    203   8239   4098080
# Corporate_Sales-East          13810.473   1486  13617  14075659
# Corporate_Sales-North         56472.003   3761  55986  62131784
# Corporate_Sales-South         37593.648   3123  37184  42692113
# Corporate_Sales-West          32149.548   2328  31840  36908821
# Delhi_NCR/Western_UP          27210.544   4513  26545  23428367
# Gujarat                       27098.824   4277  26416  24235062
# Jharkhand/Odisha               8446.702   1671   8188   6503725
# Karnataka/Kerala              31229.900   7275  30078  25165767
# Madhya_Pradesh/Chhattisgarh   19094.441   2750  18719  15288082
# Maharashtra                   35503.972   5652  34654  31181917
# Project_Sales-East             1285.225     60   1276   2358010
# Project_Sales-North           12810.620    490  12752  24772158
# Project_Sales-South           11515.107    529  11442  31848218
# Project_Sales-West            16042.685    607  15984  38745680
# Punjab/Haryana                 9864.133   1680   9606   9045618
# Rajasthan                      6301.021   1075   6135   5211320
# WB/North_East                 34277.990   6855  33175  27480968
#
# [21 rows x 21 columns]

# %%
import matplotlib.pyplot as plt

Team_Name = [Team_Name for Team_Name, df in df2.groupby('Team_Name')]

plt.bar(Team_Name, results['Sales'])
plt.xticks(Team_Name, rotation ='vertical', size=12)
plt.xlabel('City Name')
plt.ylabel('Sales in SQM')
plt.show()

# %%
# Where was the most supply ?


plt.figure(figsize=(50,30.5))
sns.countplot(df2['Team_Name'])
plt.xticks(rotation='vertical',size=60)
plt.yticks(rotation='horizontal',size=55)
plt.show()
# Out:
# C:\Users\Anjali\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
#Best Selling Products

# %%
#Inserting Product Column

df2["Product"]=df2["MATERIAL DESCRIPTION"].str[0:4]
df2["Product"]=df2["Product"].astype(str)
df2
# Out:
#        INV CREATION DT  SALES ORDER  BILL TO CODE  Ship To Code  \
# 0           01-04-2022   3100077188     100001859     100001859
# 1           01-04-2022   3100077188     100001859     100001859
# 2           01-04-2022   3100079271     100001257     100001257
# 3           01-04-2022   3100079271     100001257     100001257
# 4           01-04-2022   3100079271     100001257     100001257
# ...                ...          ...           ...           ...
# 14450       18-05-2022   3100082800     100002028     100002028
# 14451       18-05-2022   3100082800     100002028     100002028
# 14452       18-05-2022   3100082800     100002028     100002028
# 14453       18-05-2022   3100082800     100002028     100002028
# 14454       18-05-2022   3100082800     100002028     100002028
#
#        Invoice Number  PLANT    BILL TO GSTIN SALES GROUP DESCRIPTION NEW  \
# 0            90000546   3400  29ABIFM0400F1ZO              Karnataka Team
# 1            90000546   3400  29ABIFM0400F1ZO              Karnataka Team
# 2          1804012199   3100  33AANCS1511L1ZD             Tamil_Nadu Team
# 3          1804012199   3100  33AANCS1511L1ZD             Tamil_Nadu Team
# 4          1804012199   3100  33AANCS1511L1ZD             Tamil_Nadu Team
# ...               ...    ...              ...                         ...
# 14450      1204004214   2300  33AABCS4855P1ZW              Corporate Team
# 14451      1204004214   2300  33AABCS4855P1ZW              Corporate Team
# 14452      1204004214   2300  33AABCS4855P1ZW              Corporate Team
# 14453      1204004214   2300  33AABCS4855P1ZW              Corporate Team
# 14454      1204004214   2300  33AABCS4855P1ZW              Corporate Team
#
#              MATERIAL DESCRIPTION MATERIAL TYPE  ...  Qty in SQM  \
# 0        AL312-AD94-3050mmx1220mm          ZFRT  ...      11.163
# 1        AL312-AD94-3660mmx1220mm          ZFRT  ...       8.930
# 2        AL332-AD73-3050mmx1220mm          ZFRT  ...      14.884
# 3        AL332-AD73-2440mmx1220mm          ZFRT  ...      11.908
# 4        AL332-AD73-3660mmx1220mm          ZFRT  ...      17.860
# ...                           ...           ...  ...         ...
# 14450  AL33D-PP1006-4000mmx1250mm          ZFRT  ...     250.000
# 14451  AL33D-PP1006-3000mmx1250mm          ZFRT  ...     236.250
# 14452  AL33D-PP1005-4000mmx1250mm          ZFRT  ...     175.000
# 14453  AL33D-PP1007-2800mmx1250mm          ZFRT  ...       7.000
# 14454  AL33D-PP1007-2500mmx1250mm          ZFRT  ...     259.375
#
#                        Material No  Sales Person Code  Aludecorian Name  \
# 0      AA0312-01-000AD94-3050X1220             T29016      Dayanand_D_S
# 1      AA0312-01-000AD94-3660X1220             T29016      Dayanand_D_S
# 2      AA0332-01-000AD73-3050X1220             T28017   Nisanth_Natesan
# 3      AA0332-01-000AD73-2440X1220             T28017   Nisanth_Natesan
# 4      AA0332-01-000AD73-3660X1220             T28017   Nisanth_Natesan
# ...                            ...                ...               ...
# 14450  AA033D-01-0PP1006-4000X1250             T29017        Pranav_P_S
# 14451  AA033D-01-0PP1006-3000X1250             T29017        Pranav_P_S
# 14452  AA033D-01-0PP1005-4000X1250             T29017        Pranav_P_S
# 14453  AA033D-01-0PP1007-2800X1250             T29017        Pranav_P_S
# 14454  AA033D-01-0PP1007-2500X1250             T29017        Pranav_P_S
#
#                      Team_Name                       Customer Name  Month  \
# 0             Karnataka/Kerala                     Mono Sign Store      4
# 1             Karnataka/Kerala                     Mono Sign Store      4
# 2      AP/Telangana/Tamil_Nadu  Sri Vijaya Plywood Private Limited      4
# 3      AP/Telangana/Tamil_Nadu  Sri Vijaya Plywood Private Limited      4
# 4      AP/Telangana/Tamil_Nadu  Sri Vijaya Plywood Private Limited      4
# ...                        ...                                 ...    ...
# 14450    Corporate_Sales-South       Sinex Systems Private Limited      5
# 14451    Corporate_Sales-South       Sinex Systems Private Limited      5
# 14452    Corporate_Sales-South       Sinex Systems Private Limited      5
# 14453    Corporate_Sales-South       Sinex Systems Private Limited      5
# 14454    Corporate_Sales-South       Sinex Systems Private Limited      5
#
#        Qty   Sales  Product
# 0       11    6428     AL31
# 1        8    5142     AL31
# 2       14   11419     AL33
# 3       11    9136     AL33
# 4       17   13703     AL33
# ...    ...     ...      ...
# 14450  250  291001     AL33
# 14451  236  274996     AL33
# 14452  175  220674     AL33
# 14453    7    8148     AL33
# 14454  259  301899     AL33
#
# [14411 rows x 32 columns]

# %%
#grouping product name
prod_sales=pd.DataFrame(df2.groupby('Product').sum()['Inv Qty'])

# %%
#sorting Prod sales column
prod_sales=prod_sales.sort_values('Inv Qty',ascending=False)

# %%
# top 10 products by sales


prod_sales[:10]
# Out:
#          Inv Qty
# Product
# AL33       68597
# AL32       15781
# AL45       12696
# AL43       11229
# Aluw        6004
# AL31        5134
# 3mm-        2381
# AL63         965
# 4mm-         559
# AW66          34

# %%
plt.figure(figsize=(30,20.5))
sns.countplot(df2['Product'])
plt.xticks(rotation='vertical',size=30)
plt.yticks(rotation='horizontal',size=25)
plt.xlabel('Product',size=50)
plt.ylabel('Quantity Ordered',size=50)
plt.show()
# Out:
# C:\Users\Anjali\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
prices = df2.groupby('Product').mean()

fig, ax1 = plt.subplots()

##ax2 = ax1.twinx()
ax1.bar(df2['Product'],df2['Inv Qty'], color='g')
ax2.plot(df2['Product'],df2['Sales'], color='b')

ax1.set_xlabel('Product Name')
ax1.set_ylabel('Quantity Ordered', color='g')
ax2.set_ylabel('Price ($)', color='b')
ax1.set_xticklabels(df2['Product'], rotation='vertical', size=8)

fig.show()
# Out:
# C:\Users\Anjali\AppData\Local\Temp\ipykernel_4868\3139471181.py:12: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax1.set_xticklabels(df2['Product'], rotation='vertical', size=8)
# C:\Users\Anjali\AppData\Local\Temp\ipykernel_4868\3139471181.py:14: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()
